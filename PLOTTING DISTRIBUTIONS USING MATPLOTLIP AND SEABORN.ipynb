# %% [markdown]
# # PLOTTING DISTRIBUTIONS

# %% [markdown]
# ## ADIDAS US SALES DATASET

# %% [markdown]
# #### An Adidas sales dataset is a collection of data that includes information on the sales of Adidas products. Adidas sales data can be useful for a variety of purposes, such as analyzing sales trends, identifying successful products or marketing campaigns, and developing strategies for future sales. There are a variety of sources that could potentially provide an Adidas sales dataset, including Adidas itself, market research firms, government agencies, or other organizations that track sales data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### The pandas library is imported as pd , matplotlib.pyplot as plt and seaborn library as sns for data visualization.

# %%
data = pd.read_csv("C://Users//indhu//OneDrive//Documents//datasets_python//Adidas US Sales Datasets (Indhumathi S).csv")

# %% [markdown]
# #### Using read_csv function the Adidas US Sales Dataset is read from the location.

# %%
data
# Out:
#            Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0     Sports Direct      1197831   19-07-2020  Northeast  New York  New York
# 1     Sports Direct      1197831   20-07-2020  Northeast  New York  New York
# 2     Sports Direct      1197831   21-07-2020  Northeast  New York  New York
# 3     Sports Direct      1197831   22-07-2020  Northeast  New York  New York
# 4     Sports Direct      1197831   23-07-2020      South     Texas   Houston
# ...             ...          ...          ...        ...       ...       ...
# 9643  Sports Direct      1128299   12-12-2021  Southeast   Georgia   Atlanta
# 9644    Foot Locker      1128299   12-12-2021  Southeast   Georgia   Atlanta
# 9645    Foot Locker      1128299   12-12-2021  Southeast   Georgia   Atlanta
# 9646    Foot Locker      1128299   12-12-2021  Southeast   Georgia   Atlanta
# 9647    Foot Locker      1128299   12-12-2021  Southeast   Georgia   Atlanta
#
# ...

# %% [markdown]
# #### This dataset is downloaded from kaggle.com

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int64
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   int64
#  8   Units Sold        9648 non-null   int64
#  9   Total Sales       9648 non-null   int64
#  10  Operating Profit  9648 non-null   int64
#  11  Operating Margin  9648 non-null   object
#  12  Sales Method      9648 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 980.0+ KB

# %% [markdown]
# #### It shows the datatype of the variable and the memory usage of the dataset.

# %%
X = list(data.iloc[:,3])
Y = list(data.iloc[:,9])
plt.bar(X, Y, color='purple')
plt.title("Region vs Total Sales")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.xticks(color='green',rotation=90,fontweight='bold',fontsize='10',horizontalalignment='right')
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Northeast'),
#   Text(1, 0, 'South'),
#   Text(2, 0, 'Midwest'),
#   Text(3, 0, 'West'),
#   Text(4, 0, 'Southeast')])

# %% [markdown]
# #### The barchart shows the relationship between the region and the total sales made. The sales happened in the south and southwest region are more while comparing to the other regions. We need to concentrate more on the Midwest region as there is less sales.

# %%
data.describe()
# Out:
#         Retailer ID  Price per Unit   Units Sold    Total Sales  \
# count  9.648000e+03     9648.000000  9648.000000    9648.000000
# mean   1.173850e+06       45.216625   256.930037   93273.437500
# std    2.636038e+04       14.705397   214.252030  141916.016727
# min    1.128299e+06        7.000000     0.000000       0.000000
# 25%    1.185732e+06       35.000000   106.000000    4254.500000
# 50%    1.185732e+06       45.000000   176.000000    9576.000000
# 75%    1.185732e+06       55.000000   350.000000  150000.000000
# max    1.197831e+06      110.000000  1275.000000  825000.000000
#
#        Operating Profit
# count       9648.000000
# mean       34425.282131
# std        54193.124141
# min            0.000000
# 25%         1922.000000
# 50%         4371.500000
# 75%        52063.000000
# max       390000.000000

# %% [markdown]
# #### Basic statistical functions of the dataset.

# %%
plt.boxplot(data['Total Sales'])
plt.show()

# %% [markdown]
# #### The boxplot shows that there are more outliers and lies in the range from 380000 to 630000. The sales had made at the minimum value of 1 to the maximum value of 823000. The mean lies at 93000 and maximum 75% of the sales happened at the value of 150000.

# %%
plt.boxplot(data['Total Sales'])
plt.yscale('log')

plt.show()

# %% [markdown]
# #### Log has been taken for the above boxplot for better understanding above the data.

# %%
plt.hist(data['Price per Unit'])
plt.show()

# %% [markdown]
# #### This histogram describes about the price of the products. It shows that company selling more products for the price between 40 to 50. There are very less products for the price above 100. The company need to concentarte more on the products priced 60 and above.

# %%
plt.scatter(data['Total Sales'], data['Operating Profit'])
plt.show()

# %% [markdown]
# #### The scatterplot shows the relationship between sales and the profit. It shows that majority of the sales had made below 280000 and also the sales had made for both profit and the negative profit. The outliers here describes that the sales for high price has taken place and also that sales has given high profit too.

# %%
sns.distplot(data['Total Sales'])
plt.show()
# Out:
# C:\Users\indhu\AppData\Local\Temp\ipykernel_14300\3061345347.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Total Sales'])

# %% [markdown]
# #### The distplot shows that majority of the sales had taken between the values from 1 to 10000. There were very less sales for the value above 600000.

# %%
sns.distplot(data['Total Sales'][:200],rug=True)
plt.show()
# Out:
# C:\Users\indhu\AppData\Local\Temp\ipykernel_14300\2877461070.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Total Sales'][:200],rug=True)

# %% [markdown]
# #### The rug plot describes above the sales. The density of the rug describes that the majority of the sales occurance. Here, the density of the rug are more between the value 115000 and 300000.

# %%
sns.distplot(data['Total Sales'],hist=False)
plt.show()
# Out:
# C:\Users\indhu\AppData\Local\Temp\ipykernel_10864\386482525.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Total Sales'],hist=False)

# %% [markdown]
# #### This distplot is without histogram. Here the trend line tells about the sales happened. The trendline is peak at the value from 1 to 100000 which describes that sales had made high during that range.

# %%
sns.boxplot(data['Price per Unit'])
plt.title('Price per Unit')

plt.show()

# %% [markdown]
# ####  The boxplot tells about the price of the products. Here the mean lies at 45 and the minimum unit price for the product is 7 and the maximum value is 110. 50% of the prices falls between 35 to 55.

# %%
plt.subplot(3,2,1)
plt.title('Sales')
sns.distplot(data['Total Sales'])

plt.subplot(3,2,2)
plt.title('Unit Price')
sns.distplot(data['Price per Unit'])

plt.subplot(3,2,3)
plt.title('Units Sold')
sns.distplot(data['Units Sold'])

plt.subplot(3,2,4)
plt.title('Profit')
sns.distplot(data['Operating Profit'])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\indhu\AppData\Local\Temp\ipykernel_14300\2955119918.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Total Sales'])
# C:\Users\indhu\AppData\Local\Temp\ipykernel_14300\2955119918.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# #### The subplot had created for the variables sales, unit price of the product, units sold and profit earned. Here, subplot is helped to compare the variables easily.

# %%
sns.jointplot(x='Total Sales',y='Operating Profit',data=data,color='lightgreen')
plt.show()

# %% [markdown]
# #### The jointplot is created to describe the realtionship between total sales and the profit earned. The majority of the sales had taken place approximately between 9000 to 150000 and the profits are gained high below 50000. There are some outlier which shows that high priced products are sold less and that gave high profit also.

# %%
data1 = data[(data['Total Sales'] >185000) & (data['Operating Profit'] >50000)]

sns.jointplot(x='Total Sales',y='Operating Profit', data=data1, kind="hex", color='purple')
plt.show()

# %% [markdown]
# #### The heat map shows about the sales and profit relationship. The dark shade indicates that majority of the sales had taken place approximately between 9500 to 200000 and the profits are gained high between 50000 to 100000.
